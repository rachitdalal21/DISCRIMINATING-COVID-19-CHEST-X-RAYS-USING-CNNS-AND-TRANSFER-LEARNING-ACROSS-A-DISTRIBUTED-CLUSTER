# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
losses = [2.39,2.30,2.29,2.25,2.22,2.21,2.20,2.20,2.21,2.19,2.18,2.17,2.17,2.16,2.16,2.15,2.14,2.15,2.15,2.14,2.13,2.13,2.13,2.12,2.13,2.12,2.11,2.10,2.10,2.11,2.09,2.10,2.09,2.09,2.09,2.09,2.08,2.07,2.08,2.08,2.06,2.07,2.06,2.06,2.05,2.05,2.04,2.04,2.03,2.03,2.01,2.03,2.02,2.00,1.99,2.10,2.03,2.00,2.00,1.97,1.93,1.88,1.88,1.85,1.81,1.81,1.79,1.78,1.72,1.71,1.66,1.66,1.57,1.54,1.50,1.47,1.42,1.40,1.30,1.33,1.28,1.21,1.23,1.14,1.12,1.20,1.07,0.99,0.96,0.96,0.90,0.86,1.17,0.86,0.81,0.77,0.74,0.77,0.75,0.71,0.70,0.69,0.69,0.68,0.67,0.67,0.65,0.65,0.63,0.64,0.62,0.62,0.62,0.60,0.59,0.60,0.59,0.59,0.57,0.58,0.57,0.56,0.57,0.56,0.55,0.57,0.56,0.57,0.54,0.56,0.55,0.53,0.54,0.54,0.55,0.53,0.53,0.54,0.53,0.53,0.54,0.52,0.52,0.52,0.51,0.52,0.52,0.52,0.51,0.52]
x_values = range(1,len(losses)+1)
plt.plot(x_values, losses)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.xticks(np.arange(min(x_values), max(x_values)+1, 10))
plt.rcParams["figure.figsize"] = (6,4)

size=15
params = {'legend.fontsize': 'large',
          'figure.figsize': (20,8),
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
plt.rcParams.update(params)

plt.show()

# %%
# SGD - 40 - 0.1
losses = [2.34,2.28,2.28,2.21,2.20,2.18,2.18,2.17,2.16,2.16,2.15,2.15,2.13,2.14,2.13,2.12,2.12,2.12,2.11,2.11,2.10,2.09,2.09,2.08,2.08,2.07,2.08,2.08,2.08,2.07,2.07,2.06,2.06,2.06,2.05,2.05,2.04,2.04,2.04,2.04]
x_values = range(1,len(losses)+1)
plt.plot(x_values, losses)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.xticks(np.arange(min(x_values), max(x_values)+1, 10))
plt.rcParams["figure.figsize"] = (6,4)


plt.show()

# %%
# ADAM - 40 - 0.1
losses = [318.68,2.27,2.27,2.27,2.27,2.27,2.28,2.27,2.27,2.27,2.27,2.27,2.27,2.28,2.27,2.27,2.27,2.27,2.27,2.27,2.27,2.27,2.27,2.27,2.28,2.27,2.27,2.28,2.27,2.27,2.27,2.27,2.27,2.27,2.27,2.27,2.27,2.27,2.28,2.27]
x_values = range(1,len(losses)+1)
plt.plot(x_values, losses)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.xticks(np.arange(min(x_values), max(x_values)+1, 10))
plt.yticks(np.arange(min(losses), max(losses)+1, 50))
plt.rcParams["figure.figsize"] = (6,4)


plt.show()

# %%
# SGD - 40 - 0.05
losses = [2.36,2.28,2.27,2.24,2.20,2.20,2.19,2.19,2.18,2.17,2.17,2.17,2.17,2.16,2.15,2.15,2.14,2.14,2.14,2.14,2.13,2.13,2.13,2.12,2.11,2.12,2.11,2.11,2.10,2.10,2.10,2.09,2.09,2.09,2.08,2.08,2.08,2.07,2.07,2.07]
x_values = range(1,len(losses)+1)
plt.plot(x_values, losses)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.xticks(np.arange(min(x_values), max(x_values)+1, 5))
# plt.yticks(np.arange(min(losses), max(losses)+1, 10))
plt.rcParams["figure.figsize"] = (6,4)


plt.show()
